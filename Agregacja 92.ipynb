# %%
import pandas as pd 
import numpy as np

# %%
products = pd.read_csv('/Users/arturdanyliv/Downloads/course-files/WA_Sales_Products_2012-14.csv')
products.head()
# Out:
#   Retailer country Order method type  Retailer type       Product line  \
# 0    United States               Fax  Outdoors Shop  Camping Equipment
# 1    United States               Fax  Outdoors Shop  Camping Equipment
# 2    United States               Fax  Outdoors Shop  Camping Equipment
# 3    United States               Fax  Outdoors Shop  Camping Equipment
# 4    United States               Fax  Outdoors Shop  Camping Equipment
#
#     Product type                    Product  Year  Quarter    Revenue  \
# 0   Cooking Gear  TrailChef Deluxe Cook Set  2012  Q1 2012   59628.66
# 1   Cooking Gear     TrailChef Double Flame  2012  Q1 2012   35950.32
# 2          Tents                  Star Dome  2012  Q1 2012   89940.48
# 3          Tents               Star Gazer 2  2012  Q1 2012  165883.41
# 4  Sleeping Bags            Hibernator Lite  2012  Q1 2012  119822.20
#
#    Quantity  Gross margin
# 0       489      0.347548
# 1       252      0.474274
# 2       147      0.352772
# ...

# %%
groups = products.groupby(by='Retailer country')
# dzielimy zbior danych ze wzgledu na wartosc Retailer country

# %%
groups.mean().head()
# mamy doczenienie z data frame ktory w wierszach zawiera kraje a w kolumnach tylko te kolumny dla ktorych wyliczenie wartosci sredniej mialy jakis sens wartosci liczbowe 
# rok zly pomysl 
# zysk dobry pomysl 
# quantity zly pomysl 
# marza brutto nie dobry pomysl
# Out:
# /var/folders/9q/x17lv7hn4c76lb205vp38pt00000gn/T/ipykernel_11685/1192469255.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   groups.mean().head()
#                          Year       Revenue    Quantity  Gross margin
# Retailer country
# Australia         2012.859482  29822.638237  545.915689      0.451174
# Austria           2012.875971  29354.380023  544.330917      0.450913
# Belgium           2012.878976  26134.385420  484.911321      0.448410
# Brazil            2012.878954  33170.824647  595.332117      0.448023
# Canada            2012.839946  41682.874366  746.098936      0.451011

# %%
groups.sum().head()
# Out:
# /var/folders/9q/x17lv7hn4c76lb205vp38pt00000gn/T/ipykernel_11685/773630138.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   groups.sum().head()
#                       Year       Revenue  Quantity  Gross margin
# Retailer country
# Australia          7377130  1.093000e+08   2000781   1641.822415
# Austria            7773727  1.133666e+08   2102206   1723.839177
# Belgium            7467781  9.695857e+07   1799021   1653.288385
# Brazil             6618346  1.090657e+08   1957452   1466.380765
# Canada            11922051  2.468877e+08   4419144   2662.767825

# %%
groups.count().head()
# ilosc obiektow w poszczegolnych kolumnach (numeryczne i znakowe )
# w calym wierszu mam yta sama wartosc bo nie bylo zadnych wartosci 0 i byly wszystkie dane okreslone
# Out:
#                   Order method type  Retailer type  Product line  \
# Retailer country
# Australia                      3665           3665          3665
# Austria                        3862           3862          3862
# Belgium                        3710           3710          3710
# Brazil                         3288           3288          3288
# Canada                         5923           5923          5923
#
#                   Product type  Product  Year  Quarter  Revenue  Quantity  \
# Retailer country
# Australia                 3665     3665  3665     3665     3665      3665
# Austria                   3862     3862  3862     3862     3862      3862
# Belgium                   3710     3710  3710     3710     3710      3710
# Brazil                    3288     3288  3288     3288     3288      3288
# Canada                    5923     5923  5923     5923     5923      5923
#
#                   Gross margin
# Retailer country
# Australia                 3639
# ...

# %%
groups.min().head()
# Out:
#                  Order method type     Retailer type       Product line  \
# Retailer country
# Australia                   E-mail  Department Store  Camping Equipment
# Austria                Sales visit  Department Store  Camping Equipment
# Belgium                        Fax  Department Store  Camping Equipment
# Brazil                      E-mail  Department Store  Camping Equipment
# Canada                      E-mail  Department Store  Camping Equipment
#
#                  Product type      Product  Year  Quarter  Revenue  Quantity  \
# Retailer country
# Australia          Binoculars  Aloe Relief  2012  Q1 2012      0.0         1
# Austria            Binoculars  Aloe Relief  2012  Q1 2012      0.0         4
# Belgium            Binoculars  Aloe Relief  2012  Q1 2012      0.0         5
# Brazil             Binoculars  Aloe Relief  2012  Q1 2012      0.0         4
# Canada             Binoculars  Aloe Relief  2012  Q1 2012      0.0         1
#
#                   Gross margin
# ...

# %%
groups.max().head()
# dla danej grupy w danej kolumnie
# Out:
#                  Order method type    Retailer type          Product line  \
# Retailer country
# Australia                      Web  Warehouse Store  Personal Accessories
# Austria                        Web  Warehouse Store  Personal Accessories
# Belgium                        Web  Warehouse Store  Personal Accessories
# Brazil                         Web  Warehouse Store  Personal Accessories
# Canada                         Web  Warehouse Store  Personal Accessories
#
#                  Product type Product  Year  Quarter    Revenue  Quantity  \
# Retailer country
# Australia               Woods    Zone  2014  Q4 2013  516135.14     20031
# Austria                 Woods    Zone  2014  Q4 2013  321202.98      9662
# Belgium                 Woods    Zone  2014  Q4 2013  310499.39     13200
# Brazil                  Woods    Zone  2014  Q4 2013  352749.39     12157
# Canada                  Woods    Zone  2014  Q4 2013  648467.60     27268
#
#                   Gross margin
# ...

# %%
products.loc[products["Retailer country"] == "Australia"].head()
# zamowienia z Austalii
# Out:
#      Retailer country Order method type Retailer type          Product line  \
# 3735        Australia         Telephone     Golf Shop  Personal Accessories
# 3736        Australia         Telephone     Golf Shop  Personal Accessories
# 3737        Australia         Telephone     Golf Shop  Personal Accessories
# 3738        Australia         Telephone     Golf Shop        Golf Equipment
# 3739        Australia         Telephone     Golf Shop        Golf Equipment
#
#      Product type                   Product  Year  Quarter   Revenue  \
# 3735      Watches      Mountain Man Digital  2012  Q1 2012   2161.34
# 3736   Binoculars               Seeker Mini  2012  Q1 2012   5689.60
# 3737   Navigation               Glacier GPS  2012  Q1 2012  17337.34
# 3738        Irons     Hailstorm Steel Irons  2012  Q1 2012  96118.50
# 3739        Irons  Hailstorm Titanium Irons  2012  Q1 2012  40149.72
#
#       Quantity  Gross margin
# 3735        53      0.509564
# 3736        70      0.507874
# ...

# %%
products.loc[(products["Retailer country"] == "Australia") &
            (products["Order method type"] == "Web") &
            (products["Retailer type"] == "Warehouse Store")].head()
# Web poszukuje tego wiersza ktory zostal wyswietlony przy uzyciu funkcji max 
# Warehouse Store
# Out:
#       Retailer country Order method type    Retailer type       Product line  \
# 12511        Australia               Web  Warehouse Store  Camping Equipment
# 12512        Australia               Web  Warehouse Store  Camping Equipment
# 12513        Australia               Web  Warehouse Store  Camping Equipment
# 12514        Australia               Web  Warehouse Store  Camping Equipment
# 12515        Australia               Web  Warehouse Store  Camping Equipment
#
#         Product type              Product  Year  Quarter  Revenue  Quantity  \
# 12511   Cooking Gear    TrailChef Canteen  2012  Q2 2012  5390.92       439
# 12512  Sleeping Bags    Hibernator Pillow  2012  Q2 2012  3529.20       204
# 12513       Lanterns         Firefly Lite  2012  Q2 2012  3516.21       243
# 12514       Lanterns  Firefly Multi-light  2012  Q2 2012  3433.32       132
# 12515       Lanterns    EverGlow Kerosene  2012  Q2 2012  4328.80       140
#
#        Gross margin
# 12511      0.460912
# ...

# %%
products.loc[(products["Retailer country"] == "Australia") &
            (products["Order method type"] == "Web") &
            (products["Retailer type"] == "Warehouse Store") &
            (products["Product line"] == "Personel Accessories") &
            (products["Product type"] == "Woods")].head()
# Personel Accessories 
# ale rekordu nie bylo z Austalii zamowione przez WEB z linii produktu Personel Accessories ktore maja Woods
# ten wiersz nie isntnieje Woods
# Out:
# Empty DataFrame
# Columns: [Retailer country, Order method type, Retailer type, Product line, Product type, Product, Year, Quarter, Revenue, Quantity, Gross margin]
# Index: []

# %%
groups["Revenue"].sum().head()
# groups obiekt grupy z tego obiektu wybieramy Revenue
# Out:
# Retailer country
# Australia    1.093000e+08
# Austria      1.133666e+08
# Belgium      9.695857e+07
# Brazil       1.090657e+08
# Canada       2.468877e+08
# Name: Revenue, dtype: float64

# %%
groups[["Revenue","Quantity"]].mean().head()
# lista kolumn na ktore ma byc wykonanan operacja
# Out:
#                        Revenue    Quantity
# Retailer country
# Australia         29822.638237  545.915689
# Austria           29354.380023  544.330917
# Belgium           26134.385420  484.911321
# Brazil            33170.824647  595.332117
# Canada            41682.874366  746.098936

# %%
# Kiedy posiadam obiekt grupy moge wylowac sum min max mean count 
# Funkcje wykonuja obliczenia dla kazdej kolumny dla ktorej dane obliczenia moga byc wykonane sum numeryczne , ilosci count wsystkie kolumny 
# group mozna listy zrobic z nazwami tych kolumn 

# Na rzecz obiektu grupy group wywołujesz metodę mean. Co zostanie zwrócone w wyniku?
# Wartosci srednie dla wszystkich kolumn numeryczny

# Na rzecz obiektu grupy group wywołujesz metodę count. Co zostanie zwrócone w wyniku?
# ilosc nie nulowych (nie NaN) policzonych osobno dla kazdej grupy i dla kazdej kolumny 

# Chcesz wyliczyć sumy dla grup zapisanych w zmiennejgroupped_data dla kolumn Income1 i Income2. Wybierz poprawną instrukcję:
# gruupped_data[["Income1","Income2"]].sum()
