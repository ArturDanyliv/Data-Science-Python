# %%
import pandas as pd 
import numpy as np

# %%
supplies = pd.read_csv('/Users/arturdanyliv/Downloads/course-files/northwind-mongo-master/suppliers.csv', usecols = ['SupplierID','CompanyName','Country'])

# %%
supplies.head()
# sprzedawca
# Out:
#    SupplierID                         CompanyName Country
# 0           1                      Exotic Liquids      UK
# 1           2          New Orleans Cajun Delights     USA
# 2           3           Grandma Kelly's Homestead     USA
# 3           4                       Tokyo Traders   Japan
# 4           5  Cooperativa de Quesos 'Las Cabras'   Spain

# %%
customers = pd.read_csv('/Users/arturdanyliv/Downloads/course-files/northwind-mongo-master/customers.csv',usecols = ['CustomerID','CompanyName','Country'])

# %%
customers.head()
# klienci
# Out:
#   CustomerID                         CompanyName  Country
# 0      ALFKI                 Alfreds Futterkiste  Germany
# 1      ANATR  Ana Trujillo Emparedados y helados   Mexico
# 2      ANTON            Antonio Moreno Taquer?­a   Mexico
# 3      AROUT                     Around the Horn       UK
# 4      BERGS                 Berglunds snabbk?¶p   Sweden

# %%
# pobieramy do obu zbiorow najbardziej charakterestyczne ogolne dane 
# sklejamy dwie tabeli

# %%
len(supplies)
# Out:
# 29

# %%
len(customers)
# Out:
# 91

# %%
supplies.append(customers)
# Customer ID nie bylo w tabeli suplies w tabeli customer nie bylo SuppliersId
# szuka wspolnych kolumn
# Out:
# /var/folders/9q/x17lv7hn4c76lb205vp38pt00000gn/T/ipykernel_18822/3341982505.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   supplies.append(customers)
#     SupplierID                         CompanyName  Country CustomerID
# 0          1.0                      Exotic Liquids       UK        NaN
# 1          2.0          New Orleans Cajun Delights      USA        NaN
# 2          3.0           Grandma Kelly's Homestead      USA        NaN
# 3          4.0                       Tokyo Traders    Japan        NaN
# 4          5.0  Cooperativa de Quesos 'Las Cabras'    Spain        NaN
# ..         ...                                 ...      ...        ...
# 86         NaN                      Wartian Herkku  Finland      WARTH
# 87         NaN              Wellington Importadora   Brazil      WELLI
# 88         NaN                White Clover Markets      USA      WHITC
# ...

# %%
df_appended = supplies.append(customers)
# Out:
# /var/folders/9q/x17lv7hn4c76lb205vp38pt00000gn/T/ipykernel_18822/906323512.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_appended = supplies.append(customers)

# %%
len(df_appended)
# Out:
# 120

# %%
df_appended.head(40)
# pierwsze 29 pozycji to sa dostawce a potem tabela customers index jest w dwoch tabelach
# Out:
#     SupplierID                             CompanyName      Country CustomerID
# 0          1.0                          Exotic Liquids           UK        NaN
# 1          2.0              New Orleans Cajun Delights          USA        NaN
# 2          3.0               Grandma Kelly's Homestead          USA        NaN
# 3          4.0                           Tokyo Traders        Japan        NaN
# 4          5.0      Cooperativa de Quesos 'Las Cabras'        Spain        NaN
# 5          6.0                                Mayumi's        Japan        NaN
# 6          7.0                            Pavlova Ltd.    Australia        NaN
# 7          8.0                 Specialty Biscuits Ltd.           UK        NaN
# 8          9.0                        PB Knäckebröd AB       Sweden        NaN
# 9         10.0               Refrescos Americanas LTDA       Brazil        NaN
# 10        11.0             Heli Süßwaren GmbH & Co. KG      Germany        NaN
# ...

# %%
df_appended = supplies.append(customers,ignore_index = True)
# Out:
# /var/folders/9q/x17lv7hn4c76lb205vp38pt00000gn/T/ipykernel_18822/1082134649.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_appended = supplies.append(customers,ignore_index = True)

# %%
len(df_appended)
# Out:
# 120

# %%
df_appended.head(40)
# pozycja 28 i 29 i kontynuacja ale NAN
# Out:
#     SupplierID                             CompanyName      Country CustomerID
# 0          1.0                          Exotic Liquids           UK        NaN
# 1          2.0              New Orleans Cajun Delights          USA        NaN
# 2          3.0               Grandma Kelly's Homestead          USA        NaN
# 3          4.0                           Tokyo Traders        Japan        NaN
# 4          5.0      Cooperativa de Quesos 'Las Cabras'        Spain        NaN
# 5          6.0                                Mayumi's        Japan        NaN
# 6          7.0                            Pavlova Ltd.    Australia        NaN
# 7          8.0                 Specialty Biscuits Ltd.           UK        NaN
# 8          9.0                        PB Knäckebröd AB       Sweden        NaN
# 9         10.0               Refrescos Americanas LTDA       Brazil        NaN
# 10        11.0             Heli Süßwaren GmbH & Co. KG      Germany        NaN
# ...

# %%
# polaczyc dwie kolumny i przechowywac dwie kolumny jako pozycja id 
supplies2 = supplies.copy()
# customer2 = customers.copy()

# %%
supplies2.rename({'SupplierID' : 'CustomerID'} , axis='columns', inplace = True)

# %%
supplies2.head(10)
# Out:
#    CustomerID                         CompanyName    Country
# 0           1                      Exotic Liquids         UK
# 1           2          New Orleans Cajun Delights        USA
# 2           3           Grandma Kelly's Homestead        USA
# 3           4                       Tokyo Traders      Japan
# 4           5  Cooperativa de Quesos 'Las Cabras'      Spain
# 5           6                            Mayumi's      Japan
# 6           7                        Pavlova Ltd.  Australia
# 7           8             Specialty Biscuits Ltd.         UK
# 8           9                    PB Knäckebröd AB     Sweden
# 9          10           Refrescos Americanas LTDA     Brazil

# %%
supplies2.append(customers).head(40)
# Out:
# /var/folders/9q/x17lv7hn4c76lb205vp38pt00000gn/T/ipykernel_18822/2342972750.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   supplies2.append(customers).head(40)
#    CustomerID                             CompanyName      Country
# 0           1                          Exotic Liquids           UK
# 1           2              New Orleans Cajun Delights          USA
# 2           3               Grandma Kelly's Homestead          USA
# 3           4                           Tokyo Traders        Japan
# 4           5      Cooperativa de Quesos 'Las Cabras'        Spain
# 5           6                                Mayumi's        Japan
# 6           7                            Pavlova Ltd.    Australia
# 7           8                 Specialty Biscuits Ltd.           UK
# 8           9                        PB Knäckebröd AB       Sweden
# ...

# %%
# Polecenie concat 
df_concatenated = pd.concat(objs=[supplies,customers])

# %%
len(df_concatenated)
# Out:
# 120

# %%
df_concatenated.head(40)
# Out:
#     SupplierID                             CompanyName      Country CustomerID
# 0          1.0                          Exotic Liquids           UK        NaN
# 1          2.0              New Orleans Cajun Delights          USA        NaN
# 2          3.0               Grandma Kelly's Homestead          USA        NaN
# 3          4.0                           Tokyo Traders        Japan        NaN
# 4          5.0      Cooperativa de Quesos 'Las Cabras'        Spain        NaN
# 5          6.0                                Mayumi's        Japan        NaN
# 6          7.0                            Pavlova Ltd.    Australia        NaN
# 7          8.0                 Specialty Biscuits Ltd.           UK        NaN
# 8          9.0                        PB Knäckebröd AB       Sweden        NaN
# 9         10.0               Refrescos Americanas LTDA       Brazil        NaN
# 10        11.0             Heli Süßwaren GmbH & Co. KG      Germany        NaN
# ...

# %%
# jezeli chce zeby postaw nowy index ktory bedzie generowany od 0 do 119 do dodac parametr ignore index
df_concatenated = pd.concat(objs=[supplies,customers],ignore_index = True )

# %%
df_concatenated.head(40)
# Out:
#     SupplierID                             CompanyName      Country CustomerID
# 0          1.0                          Exotic Liquids           UK        NaN
# 1          2.0              New Orleans Cajun Delights          USA        NaN
# 2          3.0               Grandma Kelly's Homestead          USA        NaN
# 3          4.0                           Tokyo Traders        Japan        NaN
# 4          5.0      Cooperativa de Quesos 'Las Cabras'        Spain        NaN
# 5          6.0                                Mayumi's        Japan        NaN
# 6          7.0                            Pavlova Ltd.    Australia        NaN
# 7          8.0                 Specialty Biscuits Ltd.           UK        NaN
# 8          9.0                        PB Knäckebröd AB       Sweden        NaN
# 9         10.0               Refrescos Americanas LTDA       Brazil        NaN
# 10        11.0             Heli Süßwaren GmbH & Co. KG      Germany        NaN
# ...

# %%
df_concatenated = pd.concat(objs=[supplies2,customers],ignore_index = True )

# %%
df_concatenated.head(40)
# Out:
#    CustomerID                             CompanyName      Country
# 0           1                          Exotic Liquids           UK
# 1           2              New Orleans Cajun Delights          USA
# 2           3               Grandma Kelly's Homestead          USA
# 3           4                           Tokyo Traders        Japan
# 4           5      Cooperativa de Quesos 'Las Cabras'        Spain
# 5           6                                Mayumi's        Japan
# 6           7                            Pavlova Ltd.    Australia
# 7           8                 Specialty Biscuits Ltd.           UK
# 8           9                        PB Knäckebröd AB       Sweden
# 9          10               Refrescos Americanas LTDA       Brazil
# 10         11             Heli Süßwaren GmbH & Co. KG      Germany
# 11         12       Plutzer Lebensmittelgroßmärkte AG      Germany
# 12         13  Nord-Ost-Fisch Handelsgesellschaft mbH      Germany
# ...
