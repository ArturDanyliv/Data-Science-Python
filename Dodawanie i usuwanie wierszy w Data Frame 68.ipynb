# %%
# PIERDOLE NIC TU NIE DZIALA

# %%
import pandas as pd 
import math as math 
import matplotlib.pyplot as plt 
import numpy as np 
frame = pd.read_csv('/Users/arturdanyliv/Downloads/course-files/sleep_time.csv',index_col='name')

# %%
frame.head()
# Out:
#                             ID       genus   vore         order  conservation  \
# name
# Cheetah                      1    Acinonyx  carni     Carnivora            lc
# Owl monkey                   2       Aotus   omni      Primates           NaN
# Mountain beaver              3  Aplodontia  herbi      Rodentia            nt
# Greater short-tailed shrew   4     Blarina   omni  Soricomorpha            lc
# Cow                          5         Bos  herbi  Artiodactyla  domesticated
#
#                             sleep_total  sleep_rem  sleep_cycle  awake  \
# name
# Cheetah                            12.1        NaN          NaN   11.9
# Owl monkey                         17.0        1.8          NaN    7.0
# Mountain beaver                    14.4        2.4          NaN    9.6
# Greater short-tailed shrew         14.9        2.3     0.133333    9.1
# Cow                                 4.0        0.7     0.666667   20.0
#
#                             brainwt   bodywt
# name
# ...

# %%
del frame['bodywt']
# 1 SPOSOB

# %%
frame.head()
# Out:
#                             ID       genus   vore         order  conservation  \
# name
# Cheetah                      1    Acinonyx  carni     Carnivora            lc
# Owl monkey                   2       Aotus   omni      Primates           NaN
# Mountain beaver              3  Aplodontia  herbi      Rodentia            nt
# Greater short-tailed shrew   4     Blarina   omni  Soricomorpha            lc
# Cow                          5         Bos  herbi  Artiodactyla  domesticated
#
#                             sleep_total  sleep_rem  sleep_cycle  awake  \
# name
# Cheetah                            12.1        NaN          NaN   11.9
# Owl monkey                         17.0        1.8          NaN    7.0
# Mountain beaver                    14.4        2.4          NaN    9.6
# Greater short-tailed shrew         14.9        2.3     0.133333    9.1
# Cow                                 4.0        0.7     0.666667   20.0
#
#                             brainwt
# name
# ...

# %%
frame.drop(axis=1,columns=['awake','brainwt'], inplace=True)
# pracuje domyslnie na wierszach bo axis = 1 a pozniej kolumna ktora ma byc usunieta 
# albo liste kolumn usunac 
# 2 SPOSOB

# %%
frame.head()
# Out:
#                             ID       genus   vore         order  conservation  \
# name
# Cheetah                      1    Acinonyx  carni     Carnivora            lc
# Owl monkey                   2       Aotus   omni      Primates           NaN
# Mountain beaver              3  Aplodontia  herbi      Rodentia            nt
# Greater short-tailed shrew   4     Blarina   omni  Soricomorpha            lc
# Cow                          5         Bos  herbi  Artiodactyla  domesticated
#
#                             sleep_total  sleep_rem  sleep_cycle
# name
# Cheetah                            12.1        NaN          NaN
# Owl monkey                         17.0        1.8          NaN
# Mountain beaver                    14.4        2.4          NaN
# Greater short-tailed shrew         14.9        2.3     0.133333
# Cow                                 4.0        0.7     0.666667

# %%
frame.drop(axis='columns',columns = 'sleep_cycle',inplace=True)
# 3 SPOSOB 
# columns = nazwa kolumny

# %%
frame.head()
# Out:
#                             ID       genus   vore         order  conservation  \
# name
# Cheetah                      1    Acinonyx  carni     Carnivora            lc
# Owl monkey                   2       Aotus   omni      Primates           NaN
# Mountain beaver              3  Aplodontia  herbi      Rodentia            nt
# Greater short-tailed shrew   4     Blarina   omni  Soricomorpha            lc
# Cow                          5         Bos  herbi  Artiodactyla  domesticated
#
#                             sleep_total  sleep_rem
# name
# Cheetah                            12.1        NaN
# Owl monkey                         17.0        1.8
# Mountain beaver                    14.4        2.4
# Greater short-tailed shrew         14.9        2.3
# Cow                                 4.0        0.7

# %%
frame.drop(columns='sleep_rem',inplace=True)
# 4 sposob najlatwiejszy okresla jakie kolumny trzeba usunac

# %%
frame.head()
# Out:
#                             ID       genus   vore         order  conservation  \
# name
# Cheetah                      1    Acinonyx  carni     Carnivora            lc
# Owl monkey                   2       Aotus   omni      Primates           NaN
# Mountain beaver              3  Aplodontia  herbi      Rodentia            nt
# Greater short-tailed shrew   4     Blarina   omni  Soricomorpha            lc
# Cow                          5         Bos  herbi  Artiodactyla  domesticated
#
#                             sleep_total
# name
# Cheetah                            12.1
# Owl monkey                         17.0
# Mountain beaver                    14.4
# Greater short-tailed shrew         14.9
# Cow                                 4.0

# %%
# USUWANIE WIERSZY 
#frame  
#frame = pd.read_csv('/Users/arturdanyliv/Downloads/course-files/sleep_time.csv',index_col='name')

# %%
# Sprawdzic czemu nie dziala 
frame.drop(axis = 0, labels = [1,2], inplace=True)
frame.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 2
#       1 # Sprawdzic czemu nie dziala
# ----> 2 frame.drop(axis = 0, labels = [1,2], inplace=True)
#       3 frame.head()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
frame.drop(axis = 'rows',labels = 3,inplace=True)
frame.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 frame.drop(axis = 'rows',labels = 3,inplace=True)
#       2 frame.head()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
frame.drop(labels=4,inplace=True)
frame.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 frame.drop(labels=4,inplace=True)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
frame.drop(5,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 frame.drop(5,inplace=True)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
bro = frame.append({'name':'Panda4','genus':np.NaN,'vore':np.NaN,'order':np.NaN,'conversation':np.NaN,'sleep_total':10},
            ignore_index=True)
# Out:
# /var/folders/9q/x17lv7hn4c76lb205vp38pt00000gn/T/ipykernel_16398/2496279008.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   bro = frame.append({'name':'Panda4','genus':np.NaN,'vore':np.NaN,'order':np.NaN,'conversation':np.NaN,'sleep_total':10},

# %%
bro.head()
# Out:
#     ID       genus   vore         order  conservation  sleep_total  sleep_rem  \
# 0  1.0    Acinonyx  carni     Carnivora            lc         12.1        NaN
# 1  2.0       Aotus   omni      Primates           NaN         17.0        1.8
# 2  3.0  Aplodontia  herbi      Rodentia            nt         14.4        2.4
# 3  4.0     Blarina   omni  Soricomorpha            lc         14.9        2.3
# 4  5.0         Bos  herbi  Artiodactyla  domesticated          4.0        0.7
#
#    sleep_cycle  awake  brainwt   bodywt name  conversation
# 0          NaN   11.9      NaN   50.000  NaN           NaN
# 1          NaN    7.0  0.01550    0.480  NaN           NaN
# 2          NaN    9.6      NaN    1.350  NaN           NaN
# 3     0.133333    9.1  0.00029    0.019  NaN           NaN
# 4     0.666667   20.0  0.42300  600.000  NaN           NaN

# %%
subset = frame[0:5]
subset
# Out:
#                             ID       genus   vore         order  conservation  \
# name
# Cheetah                      1    Acinonyx  carni     Carnivora            lc
# Owl monkey                   2       Aotus   omni      Primates           NaN
# Mountain beaver              3  Aplodontia  herbi      Rodentia            nt
# Greater short-tailed shrew   4     Blarina   omni  Soricomorpha            lc
# Cow                          5         Bos  herbi  Artiodactyla  domesticated
#
#                             sleep_total  sleep_rem  sleep_cycle  awake  \
# name
# Cheetah                            12.1        NaN          NaN   11.9
# Owl monkey                         17.0        1.8          NaN    7.0
# Mountain beaver                    14.4        2.4          NaN    9.6
# Greater short-tailed shrew         14.9        2.3     0.133333    9.1
# Cow                                 4.0        0.7     0.666667   20.0
#
#                             brainwt   bodywt
# name
# ...

# %%
frame.head()
# Out:
#                             ID       genus   vore         order  conservation  \
# name
# Cheetah                      1    Acinonyx  carni     Carnivora            lc
# Owl monkey                   2       Aotus   omni      Primates           NaN
# Mountain beaver              3  Aplodontia  herbi      Rodentia            nt
# Greater short-tailed shrew   4     Blarina   omni  Soricomorpha            lc
# Cow                          5         Bos  herbi  Artiodactyla  domesticated
#
#                             sleep_total  sleep_rem  sleep_cycle  awake  \
# name
# Cheetah                            12.1        NaN          NaN   11.9
# Owl monkey                         17.0        1.8          NaN    7.0
# Mountain beaver                    14.4        2.4          NaN    9.6
# Greater short-tailed shrew         14.9        2.3     0.133333    9.1
# Cow                                 4.0        0.7     0.666667   20.0
#
#                             brainwt   bodywt
# name
# ...
