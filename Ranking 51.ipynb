# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import math as math 
frame = pd.read_csv('/Users/arturdanyliv/Downloads/course-files/Mcdonalds.csv',usecols=['Item','Category','Serving Size','Calories','TotalFat'])

# %%
frame.head()
# ranking to nie tlko sortowanie danych to rozniez przepisanie okreslonych miejs w tym rankingu wszystkim pozycja ktore sa w danych 
# punkty rankingowe a pozniej miejsc w rankingu
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    TotalFat
# 0      13.0
# 1       8.0
# 2      23.0
# 3      28.0
# 4      23.0

# %%
frame['Calories'].rank().head()
# zwraca obiekt serii rank()
# pozycja numer 0 egg mcmuffin otrzynuje pozycje 115
# i tak dalej 
# 1 wada ranking zobaczylismy w odrebnej serii
# Out:
# 0    115.0
# 1     82.5
# 2    146.0
# 3    178.5
# 4    156.0
# Name: Calories, dtype: float64

# %%
frame['CaloriesRank'] = frame['Calories'].rank()

# %%
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    TotalFat  CaloriesRank
# 0      13.0         115.0
# 1       8.0          82.5
# 2      23.0         146.0
# 3      28.0         178.5
# 4      23.0         156.0

# %%
frame.sort_values(by = 'Calories').head(10)
# Out:
#          Category                     Item  Serving Size  Calories  TotalFat  \
# 125     Beverages   Diet Dr Pepper (Child)  12 fl oz cup         0       0.0
# 138  Coffee & Tea        Iced Tea (Medium)  21 fl oz cup         0       0.0
# 137  Coffee & Tea         Iced Tea (Small)  16 fl oz cup         0       0.0
# 136     Beverages      Dasani Water Bottle    16.9 fl oz         0       0.0
# 145  Coffee & Tea           Coffee (Small)  12 fl oz cup         0       0.0
# 147  Coffee & Tea           Coffee (Large)  16 fl oz cup         0       0.0
# 124     Beverages   Diet Dr Pepper (Large)  30 fl oz cup         0       0.0
# 139  Coffee & Tea         Iced Tea (Large)  30 fl oz cup         0       0.0
# 122     Beverages   Diet Dr Pepper (Small)  16 fl oz cup         0       0.0
# 123     Beverages  Diet Dr Pepper (Medium)  21 fl oz cup         0       0.0
#
#      CaloriesRank
# 125           8.5
# 138           8.5
# 137           8.5
# 136           8.5
# 145           8.5
# ...

# %%
frame.sort_values(by = 'Calories').head(20)
# Out:
#            Category                              Item      Serving Size  \
# 125       Beverages            Diet Dr Pepper (Child)      12 fl oz cup
# 138    Coffee & Tea                 Iced Tea (Medium)      21 fl oz cup
# 137    Coffee & Tea                  Iced Tea (Small)      16 fl oz cup
# 136       Beverages               Dasani Water Bottle        16.9 fl oz
# 145    Coffee & Tea                    Coffee (Small)      12 fl oz cup
# 147    Coffee & Tea                    Coffee (Large)      16 fl oz cup
# 124       Beverages            Diet Dr Pepper (Large)      30 fl oz cup
# 139    Coffee & Tea                  Iced Tea (Large)      30 fl oz cup
# 122       Beverages            Diet Dr Pepper (Small)      16 fl oz cup
# 123       Beverages           Diet Dr Pepper (Medium)      21 fl oz cup
# 117       Beverages                 Diet Coke (Child)      12 fl oz cup
# 116       Beverages                 Diet Coke (Large)      30 fl oz cup
# ...

# %%
frame['CaloriesRank'] = frame['Calories'].rank(ascending=False)
# rank(...)
# 1. method='averaga' mozna wykorzystac rozne metody budowania rankingu i to ze uzyskywalismy miejsca w rankigu 8.5 z tego averag
# 2. numric_only = None mozna okreslac czy rankingi moga byc budowan tylko ze wzgledu na wartosci numeryczne 
# 3. asceding zawsze ruwna sie true

# %%
frame.sort_values(by = 'Calories',ascending=False).head()
# sortujemy w katgorii maljaco
# Out:
#           Category                                               Item  \
# 82  Chicken & Fish                       Chicken McNuggets (40 piece)
# 32       Breakfast        Big Breakfast with Hotcakes (Large Biscuit)
# 31       Breakfast      Big Breakfast with Hotcakes (Regular Biscuit)
# 34       Breakfast  Big Breakfast with Hotcakes and Egg Whites (La...
# 33       Breakfast  Big Breakfast with Hotcakes and Egg Whites (Re...
#
#        Serving Size  Calories  TotalFat  CaloriesRank
# 82  22.8 oz (646 g)      1880     118.0         260.0
# 32  15.3 oz (434 g)      1150      60.0         259.0
# 31  14.8 oz (420 g)      1090      56.0         258.0
# 34  15.4 oz (437 g)      1050      50.0         257.0
# 33  14.9 oz (423 g)       990      46.0         256.0

# %%
frame.sort_values(by = 'Calories',ascending=False,inplace=True)
# nadani numerow poszczegolnych wartosci 
# 3 najwieksze dania 
# inplace w ramach tego obiektu

# %%
frame.head(3)
# Out:
#           Category                                           Item  \
# 82  Chicken & Fish                   Chicken McNuggets (40 piece)
# 32       Breakfast    Big Breakfast with Hotcakes (Large Biscuit)
# 31       Breakfast  Big Breakfast with Hotcakes (Regular Biscuit)
#
#        Serving Size  Calories  TotalFat  CaloriesRank
# 82  22.8 oz (646 g)      1880     118.0         260.0
# 32  15.3 oz (434 g)      1150      60.0         259.0
# 31  14.8 oz (420 g)      1090      56.0         258.0

# %%
frame.nlargest(n=3, columns='Calories')
# nlargest chodzi nam o largest 
# n=3 3 obiekty
# Out:
#           Category                                           Item  \
# 82  Chicken & Fish                   Chicken McNuggets (40 piece)
# 32       Breakfast    Big Breakfast with Hotcakes (Large Biscuit)
# 31       Breakfast  Big Breakfast with Hotcakes (Regular Biscuit)
#
#        Serving Size  Calories  TotalFat  CaloriesRank
# 82  22.8 oz (646 g)      1880     118.0         260.0
# 32  15.3 oz (434 g)      1150      60.0         259.0
# 31  14.8 oz (420 g)      1090      56.0         258.0

# %%
frame.tail(3)
# 3 najmnij kaloryczne dania
# Out:
#          Category                Item  Serving Size  Calories  TotalFat  \
# 115     Beverages  Diet Coke (Medium)  21 fl oz cup         0       0.0
# 114     Beverages   Diet Coke (Small)  16 fl oz cup         0       0.0
# 146  Coffee & Tea     Coffee (Medium)  16 fl oz cup         0       0.0
#
#      CaloriesRank
# 115           8.5
# 114           8.5
# 146           8.5

# %%
frame.nsmallest(n=3,columns='Calories')
# 2 sposob
# Out:
#          Category              Item  Serving Size  Calories  TotalFat  \
# 145  Coffee & Tea    Coffee (Small)  12 fl oz cup         0       0.0
# 140  Coffee & Tea  Iced Tea (Child)  12 fl oz cup         0       0.0
# 139  Coffee & Tea  Iced Tea (Large)  30 fl oz cup         0       0.0
#
#      CaloriesRank
# 145           8.5
# 140           8.5
# 139           8.5
