# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %%
pok = pd.read_csv("/Users/arturdanyliv/Downloads/course-files/pokemon.csv",usecols=['Name'],squeeze=True)
pok
# Out:
# /var/folders/9q/x17lv7hn4c76lb205vp38pt00000gn/T/ipykernel_88320/3544662254.py:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   pok = pd.read_csv("/Users/arturdanyliv/Downloads/course-files/pokemon.csv",usecols=['Name'],squeeze=True)
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
type(pok)
# Out:
# pandas.core.series.Series

# %%
len (pok)
# Out:
# 800

# %%
pok.head()
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
sorted(pok)
# Out:
# ['Abomasnow',
#  'AbomasnowMega Abomasnow',
#  'Abra',
#  'Absol',
#  'AbsolMega Absol',
#  'Accelgor',
#  'AegislashBlade Forme',
#  'AegislashShield Forme',
#  'Aerodactyl',
#  'AerodactylMega Aerodactyl',
#  'Aggron',
#  'AggronMega Aggron',
#  'Aipom',
#  'Alakazam',
#  'AlakazamMega Alakazam',
#  'Alomomola',
#  'Altaria',
#  'AltariaMega Altaria',
#  'Amaura',
#  'Ambipom',
#  'Amoonguss',
#  'Ampharos',
#  'AmpharosMega Ampharos',
#  'Anorith',
#  'Arbok',
#  'Arcanine',
#  'Arceus',
#  'Archen',
#  'Archeops',
#  'Ariados',
#  'Armaldo',
#  'Aromatisse',
#  'Aron',
#  'Articuno',
#  'Audino',
#  'AudinoMega Audino',
#  'Aurorus',
#  'Avalugg',
#  'Axew',
#  'Azelf',
#  'Azumarill',
#  'Azurill',
#  'Bagon',
#  'Baltoy',
#  'Banette',
#  'BanetteMega Banette',
#  'Barbaracle',
#  'Barboach',
#  'Basculin',
#  'Bastiodon',
#  'Bayleef',
#  'Beartic',
#  'Beautifly',
#  'Beedrill',
#  'BeedrillMega Beedrill',
#  'Beheeyem',
#  'Beldum',
#  'Bellossom',
#  'Bellsprout',
# ...

# %%
sorted(pok.head(5)) # ulozzone alfabetycznie
# Out:
# ['Bulbasaur', 'Charmander', 'Ivysaur', 'Venusaur', 'VenusaurMega Venusaur']

# %%
type(sorted(pok.head(5)))
# Out:
# list

# %%
list(pok.head())
# Out:
# ['Bulbasaur', 'Ivysaur', 'Venusaur', 'VenusaurMega Venusaur', 'Charmander']

# %%
type(list(pok.head(5)))
# Out:
# list

# %%
dict(pok.head()) # Tworzymy slownik
# Out:
# {0: 'Bulbasaur',
#  1: 'Ivysaur',
#  2: 'Venusaur',
#  3: 'VenusaurMega Venusaur',
#  4: 'Charmander'}

# %%
type(dict(pok.head()))
# Out:
# dict

# %%
min(pok)
# Out:
# 'Abomasnow'

# %%
max(pok)
# Out:
# 'Zygarde50% Forme'

# %%
pok.name
# Out:
# 'Name'

# %%
pok.name = 'Name of pokemon'

# %%
pok.head()
# pok.dtype = 'Pokemony' ---> mozna jeszcze napisac
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name of pokemon, dtype: object

# %%
speed = pd.read_csv("/Users/arturdanyliv/Downloads/course-files/pokemon.csv",usecols=['Speed'],squeeze=True)
speed
# Out:
# /var/folders/9q/x17lv7hn4c76lb205vp38pt00000gn/T/ipykernel_88320/4024587284.py:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   speed = pd.read_csv("/Users/arturdanyliv/Downloads/course-files/pokemon.csv",usecols=['Speed'],squeeze=True)
# 0       45
# 1       60
# 2       80
# 3       80
# 4       65
#       ...
# 795     50
# 796    110
# 797     70
# 798     80
# 799     70
# Name: Speed, Length: 800, dtype: int64

# %%
speed.head() # Name speed
# Out:
# 0    45
# 1    60
# 2    80
# 3    80
# 4    65
# Name: Speed, dtype: int64

# %%
speed.name = 'Speed of Pokemon'

# %%
speed.head(10)
# Out:
# 0     45
# 1     60
# 2     80
# 3     80
# 4     65
# 5     80
# 6    100
# 7    100
# 8    100
# 9     43
# Name: Speed of Pokemon, dtype: int64

# %%
sorted(speed.head(10))
# Out:
# [43, 45, 60, 65, 80, 80, 80, 100, 100, 100]
